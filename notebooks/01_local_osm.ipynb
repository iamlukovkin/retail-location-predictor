# %%
from database.db import get_engine
import geopandas as gpd

engine = get_engine()
gdf = gpd.read_postgis("SELECT * FROM planet_osm_point LIMIT 1000;", con=engine, geom_col='way')
print(gdf.head())
# Out:
#         osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0  12355096415   None           None             None               None
# 1    259795058   None           None             None               None
# 2    952302312   None           None             None               None
# 3   2031099039   None           None             None               None
# 4  10206724900   None           None             None               None
#
#   admin_level aerialway aeroway amenity  area  ... tower:type tunnel water  \
# 0        None      None    None    None  None  ...       None   None  None
# 1        None      None    None    None  None  ...       None   None  None
# 2        None      None    None    None  None  ...       None   None  None
# 3        None      None    None    None  None  ...       None   None  None
# 4        None      None    None    None  None  ...       None   None  None
#
#   waterway wetland width  wood z_order  \
# 0     None    None  None  None    None
# 1     None    None  None  None    None
# 2     None    None  None  None    None
# 3     None    None  None  None    None
# 4     None    None  None  None    None
#
#                                                 tags  \
# 0  {'crossing': 'traffic_signals', 'tactile_pavin...
# 1                                                 {}
# 2                                    {'tram': 'yes'}
# 3  {'crossing': 'traffic_signals', 'tactile_pavin...
# 4                               {'entrance': 'main'}
#
#                                way
# 0  POINT (4185992.765 7485995.936)
# 1  POINT (4185998.442 7486012.522)
# 2  POINT (4186039.575 7486068.668)
# 3  POINT (4185956.375 7485962.568)
# 4  POINT (4185911.602 7485974.421)
#
# [5 rows x 70 columns]
